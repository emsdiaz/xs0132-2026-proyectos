# %% [markdown]
# # Proyecto de Redes Neuronales - Clasificación de Imágenes
# **Grupo:** Grupo Ejemplo Test
# **Integrantes:** Estudiante A, Estudiante B
#
# ## 1. Carga de Datos y Preprocesamiento
# Cargamos las imágenes pero no aplicamos ninguna técnica de Data Augmentation ni normalización.

# %%
import torch
import torchvision
import torchvision.transforms as transforms

# Carga directa sin normalización
transform = transforms.ToTensor()
print("Datos cargados sin transformaciones avanzadas.")

# %% [markdown]
# ## 2. Definición del Modelo
# Definimos la arquitectura convolucional.

# %%
import torch.nn as nn
import torch.nn.functional as F

class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, 3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(16 * 16 * 16, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = x.view(-1, 16 * 16 * 16)
        x = self.fc1(x)
        return x

model = SimpleCNN()
print(model)

# %% [markdown]
# ## 3. Entrenamiento y Resultados
# Entrenamos el modelo durante 1 época sin graficar curvas de aprendizaje ni matriz de confusión.

# %%
# Falta definir función de pérdida y optimizador
print("Entrenamiento finalizado sin métricas de evaluación detalladas.")
